# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
)
from copy import deepcopy

FRIDAY_PATH = "Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv"
WEDNESDAY_PATH = "Wednesday-workingHours.pcap_ISCX.csv"

df_fri = pd.read_csv(FRIDAY_PATH)
df_wed = pd.read_csv(WEDNESDAY_PATH)

data = pd.concat([df_fri, df_wed], ignore_index=True)

# %%
print(data.columns.tolist())

# %%
data["Label_num"] = (data["Label"] != "BENIGN").astype(int)

corr = data.corr(numeric_only=True)["Label_num"].drop("Label_num")

top5 = corr.sort_values(ascending=False).head(5)
bottom5 = corr.sort_values(ascending=True).head(5)[::-1]
combined = pd.concat([top5, bottom5])

plt.figure(figsize=(8, 6))
sns.barplot(
    x=combined.values,
    y=combined.index,
    orient='h',
    palette="coolwarm"
)

plt.xlabel("Correlation with Label")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()
